# %% [markdown]
# #### To-Do:
# - We need to check for the number of relatives survived. this can be done by using the Last name
# > complexity would be to do the same in test data.
#
# #### Done:
# Pipeline
# - Family size is calculated using SibSp and Parch.
#
# Learning exercise from: https://www.kaggle.com/ash316/eda-to-prediction-dietanic

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
data = pd.read_csv('input/train.csv', index_col='PassengerId')

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
def calcFamilySize(data):
    data['FamilySize'] = data['SibSp'] + data['Parch']
    return data

data = calcFamilySize(data)
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
# check for the number of null.

data.isnull().sum()
# Out:
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age           177
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin         687
# Embarked        2
# FamilySize      0
# dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#learnt from: https://www.kaggle.com/ash316/eda-to-prediction-dietanic

f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
# show the survival ratio by gender
data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
data[['Sex','Survived']].groupby(['Sex']).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
data.Survived

pd.crosstab(data.Pclass, data.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_21962c12_cb73_11e7_a422_8c8590179355row0_col0 {
#             background-color:  #ffff66;
#         }    #T_21962c12_cb73_11e7_a422_8c8590179355row0_col1 {
#             background-color:  #cee666;
#         }    #T_21962c12_cb73_11e7_a422_8c8590179355row0_col2 {
#             background-color:  #f4fa66;
#         }    #T_21962c12_cb73_11e7_a422_8c8590179355row1_col0 {
#             background-color:  #f6fa66;
#         }    #T_21962c12_cb73_11e7_a422_8c8590179355row1_col1 {
#             background-color:  #ffff66;
#         }    #T_21962c12_cb73_11e7_a422_8c8590179355row1_col2 {
#             background-color:  #ffff66;
#         }    #T_21962c12_cb73_11e7_a422_8c8590179355row2_col0 {
#             background-color:  #60b066;
#         }    #T_21962c12_cb73_11e7_a422_8c8590179355row2_col1 {
#             background-color:  #dfef66;
#         }    #T_21962c12_cb73_11e7_a422_8c8590179355row2_col2 {
#             background-color:  #90c866;
# ...

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
data['Pclass'].value_counts().plot.bar(color=('orange','yellow','gray'), ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')

sns.countplot('Pclass', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Pclass:Survived vs non')
plt.show()

# %%
data[['Pclass', 'Survived']].groupby(['Pclass', 'Survived'])['Survived'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
data[['Pclass', 'Survived', 'Sex']].groupby(['Pclass', 'Sex', 'Survived'])['Survived'].count()
# Out:
# Pclass  Sex     Survived
# 1       female  0             3
#                 1            91
#         male    0            77
#                 1            45
# 2       female  0             6
#                 1            70
#         male    0            91
#                 1            17
# 3       female  0            72
#                 1            72
#         male    0           300
#                 1            47
# Name: Survived, dtype: int64

# %%
pd.crosstab([data.Sex, data.Survived],
            [data.Pclass, data.SibSp],
            margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_d03c2346_cb95_11e7_9e87_8c8590179355row0_col0 {
#             background-color:  #ffff66;
#         }    #T_d03c2346_cb95_11e7_9e87_8c8590179355row0_col1 {
#             background-color:  #ffff66;
#         }    #T_d03c2346_cb95_11e7_9e87_8c8590179355row0_col2 {
#             background-color:  #ffff66;
#         }    #T_d03c2346_cb95_11e7_9e87_8c8590179355row0_col3 {
#             background-color:  #ffff66;
#         }    #T_d03c2346_cb95_11e7_9e87_8c8590179355row0_col4 {
#             background-color:  #ffff66;
#         }    #T_d03c2346_cb95_11e7_9e87_8c8590179355row0_col5 {
#             background-color:  #ffff66;
#         }    #T_d03c2346_cb95_11e7_9e87_8c8590179355row0_col6 {
#             background-color:  #ffff66;
#         }    #T_d03c2346_cb95_11e7_9e87_8c8590179355row0_col7 {
#             background-color:  #ffff66;
#         }    #T_d03c2346_cb95_11e7_9e87_8c8590179355row0_col8 {
#             background-color:  #ffff66;
# ...

# %%
pd.crosstab([data.Sex, data.Survived],
            [data.Pclass, data.Parch],
            margins=True).style.background_gradient(cmap='summer_r').set_properties(**{'border-color': 'black'})
# Out:
# <style  type="text/css" >
#     #T_9e6f7412_cb95_11e7_b1b9_8c8590179355row0_col0 {
#             background-color:  #ffff66;
#             border-color:  black;
#         }    #T_9e6f7412_cb95_11e7_b1b9_8c8590179355row0_col1 {
#             background-color:  #ffff66;
#             border-color:  black;
#         }    #T_9e6f7412_cb95_11e7_b1b9_8c8590179355row0_col2 {
#             background-color:  #ffff66;
#             border-color:  black;
#         }    #T_9e6f7412_cb95_11e7_b1b9_8c8590179355row0_col3 {
#             background-color:  #ffff66;
#             border-color:  black;
#         }    #T_9e6f7412_cb95_11e7_b1b9_8c8590179355row0_col4 {
#             background-color:  #ffff66;
#             border-color:  black;
#         }    #T_9e6f7412_cb95_11e7_b1b9_8c8590179355row0_col5 {
#             background-color:  #ffff66;
#             border-color:  black;
#         }    #T_9e6f7412_cb95_11e7_b1b9_8c8590179355row0_col6 {
#             background-color:  #ffff66;
# ...

# %%
sns.countplot('Sex', hue='Pclass', data = data)
plt.show()

# %%
sns.countplot('Pclass', hue='Sex', data = data)
plt.show()

# %% [markdown]
# - number of passengers: p3 > p1 > p2
# - male and female: p3 > p2 > p1
# - larger difference in male and female numbers in P3. ~ 2 : 1
# - larger difference in class in male, p3. 3 : 1 : 1.

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data = data)

# %%
pd.crosstab([data.Sex, data.Survived], data.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6f79029c_cb96_11e7_b081_8c8590179355row0_col0 {
#             background-color:  #ffff66;
#         }    #T_6f79029c_cb96_11e7_b081_8c8590179355row0_col1 {
#             background-color:  #ffff66;
#         }    #T_6f79029c_cb96_11e7_b081_8c8590179355row0_col2 {
#             background-color:  #f1f866;
#         }    #T_6f79029c_cb96_11e7_b081_8c8590179355row0_col3 {
#             background-color:  #ffff66;
#         }    #T_6f79029c_cb96_11e7_b081_8c8590179355row1_col0 {
#             background-color:  #96cb66;
#         }    #T_6f79029c_cb96_11e7_b081_8c8590179355row1_col1 {
#             background-color:  #a3d166;
#         }    #T_6f79029c_cb96_11e7_b081_8c8590179355row1_col2 {
#             background-color:  #f1f866;
#         }    #T_6f79029c_cb96_11e7_b081_8c8590179355row1_col3 {
#             background-color:  #cfe766;
#         }    #T_6f79029c_cb96_11e7_b081_8c8590179355row2_col0 {
#             background-color:  #a7d366;
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()
